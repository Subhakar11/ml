# %%
import pandas as pd
import pytesseract
import re
from PIL import Image

# Function to extract the value for the given entity from the image text
def extract_value_from_text(text, entity_name):
    text = text.lower()  # Normalize text to lowercase
    
    entity_patterns = {
        'width': r'(\d+(\.\d+)?)\s*(cm|mm|inches|inch)',
        'height': r'(\d+(\.\d+)?)\s*(cm|mm|inches|inch)',
        'depth': r'(\d+(\.\d+)?)\s*(cm|mm|inches|inch)',
        'voltage': r'(\d+(\.\d+)?)\s*(volt|v)',
        'wattage': r'(\d+(\.\d+)?)\s*(watt|kw|w)',
        'item_weight': r'(\d+(\.\d+)?)\s*(kg|g|gram|ton)',
        'maximum_weight_recommendation': r'(\d+(\.\d+)?)\s*(kg|g|gram|ton)'
    }
    
    pattern = entity_patterns.get(entity_name)
    
    if pattern:
        match = re.search(pattern, text)
        if match:
            value = match.group(1)  # Extract the numeric value
            unit = match.group(3)   # Extract the unit
            return f"{value} {unit}"
    
    return ""

# Process a single image to extract the entity value
def process_image(image_path, entity_name):
    try:
        img = Image.open(image_path)
        extracted_text = pytesseract.image_to_string(img)
        return extract_value_from_text(extracted_text, entity_name)
    except Exception as e:
        print(f"Error processing image {image_path}: {e}")
        return ""

# Main function to process the entire DataFrame and predict values
def predict_entity_values(df, image_folder):
    predictions = []

    for index, row in df.iterrows():
        image_path = f"{image_folder}/{row['index']}.jpg"  # Assuming image files are named by index
        entity_name = row['entity_name']
        
        # Process the image and get the prediction
        prediction = process_image(image_path, entity_name)
        
        # Append the result to the list
        predictions.append({
            'index': row['index'],
            'prediction': prediction if prediction else ""  # Return empty string if no prediction
        })
    
    # Convert the predictions list to a DataFrame
    prediction_df = pd.DataFrame(predictions)
    
    # Save to CSV
    prediction_df.to_csv('predictions.csv', index=False)

    return prediction_df

# Example usage
df = pd.read_csv('/Users/kaustubh/Downloads/student_resource 3/dataset/sample_test.csv')  # Load the test dataset
image_folder = '/Users/kaustubh/Downloads/student_resource 3/images'  # Folder where images are downloaded
result_df = predict_entity_values(df, image_folder)
print(result_df.head())
# Out:
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/0.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/0.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/1.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/1.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/2.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/2.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/3.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/3.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/4.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/4.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/5.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/5.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/6.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/6.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/7.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/7.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/8.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/8.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/9.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/9.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/10.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/10.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/11.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/11.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/12.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/12.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/13.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/13.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/14.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/14.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/15.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/15.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/16.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/16.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/17.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/17.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/18.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/18.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/19.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/19.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/20.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/20.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/21.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/21.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/22.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/22.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/23.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/23.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/24.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/24.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/25.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/25.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/26.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/26.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/27.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/27.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/28.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/28.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/29.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/29.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/30.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/30.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/31.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/31.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/32.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/32.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/33.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/33.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/34.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/34.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/35.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/35.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/36.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/36.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/37.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/37.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/38.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/38.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/39.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/39.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/40.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/40.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/41.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/41.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/42.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/42.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/43.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/43.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/44.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/44.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/45.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/45.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/46.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/46.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/47.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/47.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/48.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/48.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/49.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/49.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/50.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/50.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/51.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/51.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/52.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/52.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/53.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/53.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/54.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/54.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/55.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/55.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/56.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/56.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/57.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/57.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/58.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/58.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/59.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/59.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/60.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/60.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/61.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/61.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/62.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/62.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/63.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/63.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/64.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/64.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/65.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/65.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/66.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/66.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/67.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/67.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/68.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/68.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/69.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/69.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/70.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/70.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/71.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/71.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/72.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/72.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/73.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/73.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/74.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/74.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/75.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/75.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/76.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/76.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/77.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/77.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/78.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/78.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/79.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/79.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/80.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/80.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/81.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/81.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/82.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/82.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/83.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/83.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/84.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/84.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/85.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/85.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/86.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/86.jpg'
# Error processing image /Users/kaustubh/Downloads/student_resource 3/images/87.jpg: [Errno 2] No such file or directory: '/Users/kaustubh/Downloads/student_resource 3/images/87.jpg'
#    index prediction
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
